# %%
import datetime

# %matplotlib inline
import matplotlib.pyplot as pd
from IPython.display import display, YouTubeVideo

import arcgis
from arcgis.gis import GIS
from arcgis.features.analyze_patterns import interpolate_points
from arcgis.geocoding import geocode
from arcgis.features.find_locations import trace_downstream
from arcgis.features.use_proximity import create_buffers

gis = GIS(profile = "your_online_profile")
# Out:
# Profile your_online_profile does not have a password on file through keyring. If you are expecting this behavior (PKI or IWA authentication, entering password through run-time prompt, etc.), please ignore this message. If you would like to store your password in the your_online_profile profile, run GIS(profile = 'your_online_profile', password = ...). See the API doc for more details. (http://bit.ly/2CK2wG8)

# %%
import datetime

# %matplotlib inline
import matplotlib.pyplot as pd
from IPython.display import display, YouTubeVideo

import arcgis
from arcgis.gis import GIS
from arcgis.features.analyze_patterns import interpolate_points
from arcgis.geocoding import geocode
from arcgis.features.find_locations import trace_downstream
from arcgis.features.use_proximity import create_buffers

gis = GIS("https://www.arcgis.com", "arcgis_python", "P@ssword123")

# %%
YouTubeVideo('x4dNIfx6HVs')

# %%
map = gis.map("Chennai")
map
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-5c857c8a-876c-4045-a132-e82bb3be5b54"><img src=""></img></div>

# %%
chennaipop = gis.content.search("Chennai_Population", 
                                item_type="Feature Layer", 
                                outside_org=True)[0]
chennaipop
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-c5309589f57b> in <module>
#       1 chennaipop = gis.content.search("Chennai_Population",
#       2                                 item_type="Feature Layer",
# ----> 3                                 outside_org=True)[0]
#       4 chennaipop
#
# IndexError: list index out of range

# %%
map.add_layer(chennaipop, {"renderer":"ClassedColorRenderer", 
                           "field_name": "TOTPOP_CY", 
                           "opacity":0.7})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ce980de01870> in <module>
# ----> 1 map.add_layer(chennaipop, {"renderer":"ClassedColorRenderer",
#       2                            "field_name": "TOTPOP_CY",
#       3                            "opacity":0.7})
#
# NameError: name 'chennaipop' is not defined

# %%
search_rainfall = gis.content.search("Chennai_precipitation", 
                              item_type="Feature Layer", 
                              outside_org=True)
if len(search_rainfall) >= 1:
    rainfall = search_rainfall[0]
else:
    # if the "Chennai_precipitation" web layer does not exist
    print("Web Layer does not exist. Re-publishing...")
    # import any pandas data frame, with an address field, as a layer in our GIS
    import pandas as pds
    df = pds.read_csv('data/Chennai_precipitation.csv')
    # Create an arcgis.features.FeatureCollection object by importing the pandas dataframe with an address field
    rainfall = gis.content.import_data(df, {"Address" : "LOCATION"})

# %%
map2 = gis.map("Tamil Nadu, India")
map2
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-888c8bf1-5151-479a-bea1-4c6cf3288df7"><img src=""></img></div>

# %%
interpolated_rf = interpolate_points(rainfall, field='RAINFALL')

# %%
intmap = gis.map("Tamil Nadu")
intmap
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-b255c247-0bbc-4e93-9624-ef7889912a19"><img src=""></img></div>

# %%
intmap.add_layer(interpolated_rf['result_layer'])

# %%
lakemap = gis.map("Chennai")
lakemap.height='450px'
lakemap
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-812bd25b-d1fe-4bfa-a1c2-ba62856cc311"><img src=""></img></div>

# %%
lakemap.draw(geocode("Chembarambakkam, Tamil Nadu")[0], 
             {"title": "Chembarambakkam", "content": "Water reservoir"})
lakemap.draw(geocode("Puzhal Lake, Tamil Nadu")[0], 
             {"title": "Puzhal", "content": "Water reservoir"})
lakemap.draw(geocode("Kannampettai, Tamil Nadu")[0], 
             {"title": "Poondi Lake ", "content": "Water reservoir"})

# %%
search_results = gis.content.search("Chennai_lakes", 
                                   item_type="Feature Layer",
                                   outside_org=True)
search_results
# Out:
# [<Item title:"chennai_lakes" type:Feature Layer Collection owner:lizgraham_gp2>,
#  <Item title:"Chennai Lakes OverFlow Path" type:Feature Layer Collection owner:Balaganesh99>,
#  <Item title:"Possible Flood Zones" type:Feature Layer Collection owner:Balaganesh99>,
#  <Item title:"Chennai_lakes" type:Feature Layer Collection owner:esri_notebook>]

# %%
chennai_lakes = search_results[2]
chennai_lakes
# Out:
# <Item title:"Possible Flood Zones" type:Feature Layer Collection owner:Balaganesh99>

# %%
downstream = trace_downstream(chennai_lakes)
downstream.query()
# Out:
# {"messageCode": "AO_100091", "message": "The input layer must be point geometry.", "params": {"paramName": "input layer"}}
# {"messageCode": "AO_100122", "message": "TraceDownstream failed."}
# Failed to execute (TraceDownstream).
# Failed.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-16-f21e3672cc78> in <module>
# ----> 1 downstream = trace_downstream(chennai_lakes)
#       2 downstream.query()
#
# ~\Anaconda3\envs\arcgispythonapi_real\lib\site-packages\arcgis\features\find_locations.py in trace_downstream(input_layer, split_distance, split_units, max_distance, max_distance_units, bounding_polygon_layer, source_database, generalize, output_name, context, gis)
#     362         generalize,
#     363         output_name,
# --> 364         context)
#
# ~\Anaconda3\envs\arcgispythonapi_real\lib\site-packages\arcgis\_impl\tools.py in trace_downstream(self, input_layer, split_distance, split_units, max_distance, max_distance_units, bounding_polygon_layer, source_database, generalize, output_name, context)
#    2462         task_url, job_info, job_id = super()._analysis_job(task, params)
#    2463
# -> 2464         job_info = super()._analysis_job_status(task_url, job_info)
#    2465         job_values = super()._analysis_job_results(task_url, job_info, job_id)
#    2466         #print(job_values)
#
# ~\Anaconda3\envs\arcgispythonapi_real\lib\site-packages\arcgis\_impl\tools.py in _analysis_job_status(self, task_url, job_info)
#     186
#     187                     if job_response.get("jobStatus") == "esriJobFailed":
# --> 188                         raise Exception("Job failed.")
#     189                     elif job_response.get("jobStatus") == "esriJobCancelled":
#     190                         raise Exception("Job cancelled.")
#
# Exception: Job failed.

# %%
floodprone_buffer = create_buffers(downstream, [ 1 ], units='Miles')

# %%
lakemap.add_layer(floodprone_buffer)

# %%
def exact_search(my_gis, title, owner_value, item_type_value, max_items_value=20):
    final_match = None
    search_result = my_gis.content.search(query= title + ' AND owner:' + owner_value, 
                                          item_type=item_type_value, max_items=max_items_value, outside_org=True)
    
    if "Imagery Layer" in item_type_value:
        item_type_value = item_type_value.replace("Imagery Layer", "Image Service")
    elif "Layer" in item_type_value:
        item_type_value = item_type_value.replace("Layer", "Service")
    
    for result in search_result:
        if result.title == title:
            final_match = result
            break
    return final_match

ls_water = exact_search(gis, 'Landsat GLS Multispectral', 'esri', 'Imagery Layer')
ls_water
# Out:
# <Item title:"Landsat GLS Multispectral" type:Imagery Layer owner:esri>

# %%
ls_water_lyr = ls_water.layers[0]

# %%
from arcgis.geocoding import geocode
area = geocode("Tamil Nadu, India", out_sr=ls_water_lyr.properties.extent.spatialReference)[0]
ls_water_lyr.extent = area['extent']

# %%
# data source option 
from arcgis.raster.functions import stretch, extract_band
target_img_layer = stretch(extract_band(ls_water_lyr, [5,4,3]),
                           stretch_type="percentclip", gamma=[1,1,1], dra=True)

# %%
import pandas as pd
from arcgis import geometry
import datetime as dt

def filter_images(my_map, start_year, end_year):
    selected = target_img_layer.filter_by(where="(Category = 1) AND (CloudCover <=0.2)",
                                          time=[dt.datetime(start_year, 1, 1), dt.datetime(end_year, 1, 1)],
                                          geometry=arcgis.geometry.filters.intersects(ls_water_lyr.extent))
    my_map.add_layer(selected)
    
    fs = selected.query(out_fields="AcquisitionDate, GroupName, Month, DayOfYear, WRS_Row, WRS_Path")
    tdf = fs.sdf  
    return tdf

# %%
satmap1 = gis.map("Pallikaranai, Tamil Nadu, India", 13)
df = filter_images(satmap1, 1991, 1992) 
df.head()
# Out:
# C:\Users\kylie\Anaconda3\envs\arcgispythonapi_real\lib\site-packages\IPython\lib\pretty.py:402: FutureWarning: 'ExtensionArray._formatting_values' is deprecated. Specify 'ExtensionArray._formatter' instead.
#   return _repr_pprint(obj, self, cycle)
# C:\Users\kylie\Anaconda3\envs\arcgispythonapi_real\lib\site-packages\pandas\io\formats\html.py:606: FutureWarning: 'ExtensionArray._formatting_values' is deprecated. Specify 'ExtensionArray._formatter' instead.
#   super().render()
#    OBJECTID AcquisitionDate            GroupName  Month  DayOfYear  WRS_Row  \
# 0     34297      1991-08-25  p142r051_5x19910825      8        237       51
# 1     34300      1991-08-25  p142r052_5x19910825      8        237       52
# 2     34341      1991-04-10  p143r051_5x19910410      4        100       51
# 3     34298      1991-01-29  p142r052_5x19910129      1         29       52
# 4     34301      1991-01-29  p142r053_5x19910129      1         29       53
#
#    WRS_Path   Shape_Length    Shape_Area  \
# 0       142  711646.676375  3.157366e+10
# 1       142  707233.012677  3.118276e+10
# 2       143  719956.694300  3.231922e+10
# 3       142  716418.700482  3.199999e+10
# 4       142  713084.857110  3.170226e+10
#
#                                                SHAPE
# 0  {"rings": [[[9024389.361699998, 1418416.124200...
# 1  {"rings": [[[8988407.6618, 1253748.178100001],...
# 2  {"rings": [[[8854469.6882, 1418030.1556000002]...
# 3  {"rings": [[[8988705.9855, 1253944.3066000007]...
# 4  {"rings": [[[8953190.746100001, 1089696.012499...

# %%
satmap2 = gis.map("Pallikaranai, Tamil Nadu, India", 13)
df = filter_images(satmap2, 2009, 2010)
df.head()
# Out:
#    OBJECTID AcquisitionDate             GroupName  Month  DayOfYear  WRS_Row  \
# 0      7062      2009-03-04  L7141053_05320090304      3         63       53
# 1      7085      2009-02-14  L7143054_05420090214      2         45       54
# 2      3112      2009-03-03  L5142053_05320090303      3         62       53
# 3      3146      2009-01-21  L5143051_05120090121      1         21       51
# 4      7094      2009-01-20  L7144052_05220090120      1         20       52
#
#    WRS_Path   Shape_Length    Shape_Area  \
# 0       141  739524.845354  3.403963e+10
# 1       143  735881.614907  3.374058e+10
# 2       142  733068.511329  3.349556e+10
# 3       143  739594.538531  3.409762e+10
# 4       144  738881.696015  3.403042e+10
#
#                                                SHAPE
# 0  {"rings": [[[9157743.0141, 1206720.0223000012]...
# 1  {"rings": [[[8780336.5403, 1043432.0866999999]...
# 2  {"rings": [[[8988128.4335, 1202891.985199999],...
# 3  {"rings": [[[8889603.408100002, 1533573.856199...
# 4  {"rings": [[[8680469.743299998, 1371205.350800...

# %%
from ipywidgets import *

satmap1.layout=Layout(flex='1 1', padding='10px', height='300px')
satmap2.layout=Layout(flex='1 1', padding='10px', height='300px')

box = HBox([satmap1, satmap2])
box
# Out:
# HBox(children=(MapView(layout=Layout(flex='1 1', height='300px', padding='10px'), zoom=13.0), MapView(layout=L…

# %%
relief_centers = gis.content.search("Chennai Relief Centers")[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-7d7b8634f5ed> in <module>
# ----> 1 relief_centers = gis.content.search("Chennai Relief Centers")[0]
#
# IndexError: list index out of range

# %%
reliefmap = gis.map("Chennai")
reliefmap
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-15de25f5-d0ec-4299-bdf3-00060eaa0483"><img src=""></img></div>

# %%
reliefmap.add_layer(chennaipop, {"opacity":0.5})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-7cd1527f2327> in <module>
# ----> 1 reliefmap.add_layer(chennaipop, {"opacity":0.5})
#
# NameError: name 'chennaipop' is not defined

# %%
reliefmap.add_layer(relief_centers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-a08e021f27ac> in <module>
# ----> 1 reliefmap.add_layer(relief_centers)
#
# NameError: name 'relief_centers' is not defined

# %%
relief_data = relief_centers.layers[0].query().sdf
relief_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-92a92613896d> in <module>
# ----> 1 relief_data = relief_centers.layers[0].query().sdf
#       2 relief_data.head()
#
# NameError: name 'relief_centers' is not defined

# %%
relief_data['No_of_pers'].sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-30cc0a4fc6cd> in <module>
# ----> 1 relief_data['No_of_pers'].sum()
#
# NameError: name 'relief_data' is not defined

# %%
relief_data['No_of_pers'].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-3ac7da059694> in <module>
# ----> 1 relief_data['No_of_pers'].describe()
#
# NameError: name 'relief_data' is not defined

# %%
relief_data['No_of_pers'].hist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-93ceaa6286f7> in <module>
# ----> 1 relief_data['No_of_pers'].hist()
#
# NameError: name 'relief_data' is not defined

# %%
relief_data.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-825de8b037d6> in <module>
# ----> 1 relief_data.shape
#
# NameError: name 'relief_data' is not defined

# %%
chennai_pop_featurelayer = chennaipop.layers[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-ae78417a32d7> in <module>
# ----> 1 chennai_pop_featurelayer = chennaipop.layers[0]
#
# NameError: name 'chennaipop' is not defined

# %%
res = arcgis.features.summarize_data.aggregate_points(  relief_centers, 
                                                        chennai_pop_featurelayer, 
                                                        False, 
                                                        ["No_of_pers Sum"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-06102b0710f9> in <module>
# ----> 1 res = arcgis.features.summarize_data.aggregate_points(  relief_centers,
#       2                                                         chennai_pop_featurelayer,
#       3                                                         False,
#       4                                                         ["No_of_pers Sum"])
#
# NameError: name 'relief_centers' is not defined

# %%
aggr_lyr = res['aggregated_layer']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-8f6dcc5ac436> in <module>
# ----> 1 aggr_lyr = res['aggregated_layer']
#
# NameError: name 'res' is not defined

# %%
reliefmap.add_layer(aggr_lyr, { "renderer": "ClassedSizeRenderer", 
                               "field_name":"SUM_No_of_pers"})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-f75418c2158c> in <module>
# ----> 1 reliefmap.add_layer(aggr_lyr, { "renderer": "ClassedSizeRenderer",
#       2                                "field_name":"SUM_No_of_pers"})
#
# NameError: name 'aggr_lyr' is not defined

# %%
df = aggr_lyr.query().sdf
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-b7cc328e7726> in <module>
# ----> 1 df = aggr_lyr.query().sdf
#       2 df.head()
#
# NameError: name 'aggr_lyr' is not defined

# %%
df = aggr_lyr.query().sdf

df2 = df[['NAME', 'SUM_No_of_pers']]
df2.set_index('NAME', inplace=True)
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-3af32894f50b> in <module>
# ----> 1 df = aggr_lyr.query().sdf
#       2
#       3 df2 = df[['NAME', 'SUM_No_of_pers']]
#       4 df2.set_index('NAME', inplace=True)
#       5 df2
#
# NameError: name 'aggr_lyr' is not defined

# %%
df2.plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-c74e83079de9> in <module>
# ----> 1 df2.plot(kind='bar')
#
# NameError: name 'df2' is not defined

# %%
routemap = gis.map("Chennai")
routemap
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-2c4a6a50-8537-4e49-af38-261e3f7e35d3"><img src=""></img></div>

# %%
nehru_stadium = geocode('Jawaharlal Nehru Stadium, Chennai')[0]
routemap.draw(nehru_stadium, {"title": "Nehru Stadium", 
                              "content": "Chennai Flood Relief Center"})

# %%
start_time = datetime.datetime(2015, 12, 13, 9, 0)

# %%
routes = arcgis.features.use_proximity.plan_routes(
    relief_centers, 
    15, 
    15, 
    start_time, 
    nehru_stadium, 
    stop_service_time=30)
routemap.add_layer(routes['routes_layer'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-ee7df13d9828> in <module>
#       1 routes = arcgis.features.use_proximity.plan_routes(
# ----> 2     relief_centers,
#       3     15,
#       4     15,
#       5     start_time,
#
# NameError: name 'relief_centers' is not defined

# %%
routemap.add_layer(routes['assigned_stops_layer'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-640063703113> in <module>
# ----> 1 routemap.add_layer(routes['assigned_stops_layer'])
#
# NameError: name 'routes' is not defined
